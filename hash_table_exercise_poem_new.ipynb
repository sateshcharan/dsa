# %%
import csv

word_count = {}

with open ('./res/poem.txt', 'r') as file:
    for line in file:
        tokens = line.split(" ")
        for token in tokens:
            token = token.replace('\n', '')
            if token in word_count:
                word_count[token] += 1
            word_count[token] = 1

# %%
word_count
# Out:
# {'Two': 1,
#  'roads': 1,
#  'diverged': 1,
#  'in': 1,
#  'a': 1,
#  'yellow': 1,
#  'wood,': 1,
#  'And': 1,
#  'sorry': 1,
#  'I': 1,
#  'could': 1,
#  'not': 1,
#  'travel': 1,
#  'both': 1,
#  'be': 1,
#  'one': 1,
#  'traveler,': 1,
#  'long': 1,
#  'stood': 1,
#  'looked': 1,
#  'down': 1,
#  'as': 1,
#  'far': 1,
#  'To': 1,
#  'where': 1,
#  'it': 1,
#  'bent': 1,
#  'the': 1,
#  'undergrowth;': 1,
#  '': 1,
#  'Then': 1,
#  'took': 1,
#  'other,': 1,
#  'just': 1,
#  'fair,': 1,
#  'having': 1,
#  'perhaps': 1,
#  'better': 1,
#  'claim,': 1,
#  'Because': 1,
#  'was': 1,
#  'grassy': 1,
#  'and': 1,
#  'wanted': 1,
#  'wear;': 1,
#  'Though': 1,
#  'for': 1,
#  'that': 1,
#  'passing': 1,
#  'there': 1,
#  'Had': 1,
#  'worn': 1,
#  'them': 1,
#  'really': 1,
#  'about': 1,
#  'same,': 1,
#  'morning': 1,
#  'equally': 1,
#  'lay': 1,
#  'In': 1,
#  'leaves': 1,
#  'no': 1,
#  'step': 1,
#  'had': 1,
#  'trodden': 1,
#  'black.': 1,
#  'Oh,': 1,
#  'kept': 1,
# ...
